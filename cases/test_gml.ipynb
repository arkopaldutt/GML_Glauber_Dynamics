# %% [markdown]
# Description:
# Python Jupyter notebook to be used when testing parts of the GraphicalModelLearning code

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# Fig1.B.
M_array_B = np.array([27400, 5050, 4250, 4650, 3000, 2500, 3450, 4250, 4050, 4650])
c_array = np.array([0.05 + 0.05*i for i in range(10)])

# %%
# Fig1.D.
M_array_D = np.array([51000, 7250, 3300, 4650, 5300, 3600, 4450, 4250, 3900, 4450])
c_array = np.array([0.05 + 0.05*i for i in range(10)])

# %%
plt.figure(figsize=(10,7))
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.plot(c_array, M_array_B, 'ob', markersize=8, fillstyle='none', label='RR-F (n=16, d=3)')
plt.plot(c_array, M_array_D, 'xr', markersize=8, fillstyle='none', label='RR-SG (n=16, d=3)')
plt.xlabel(r"$c_\lambda$")
plt.ylabel(r"$m^\star$")
plt.legend(loc='best')
#plt.title('Sensitivity of Sample Complexity for GD-RPLE in M-regime')
title_plot='sensitivity_D-RPLE_Mregime_RR.png'
plt.savefig(title_plot, dpi=300, bbox_inches='tight')

# %%
# regularization value
c_array = []
c_array.extend([0.02,0.04])
c_array.extend([0.05 + 0.05*i for i in range(10)])
c_array = np.array(c_array)

# Lattices
M_array_A = np.array([27100, 22400, 32850, 74550, 104750, 187750, 
                      277200, 336850, 473750, 522250, 699700, 771350])

# %%
plt.figure(figsize=(10,7))
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.semilogy(c_array, M_array_A, 'sg', fillstyle='none', label='Fig.1A (Lattice-F)')
plt.xlabel(r"$c_\lambda$")
plt.ylabel(r"$m^\star$")
plt.legend(loc='best')
#plt.title('Sensitivity of Sample Complexity for GD-RPLE in M-regime')
title_plot='sensitivity_GD-RPLE_Mregime_LatticeA.png'
plt.savefig(title_plot, bbox_inches='tight')

# %% [markdown]
# ## GD-RISE

# %%
# regularization values
c_array = []
c_array.extend([0.02,0.04])
c_array.extend([0.05 + 0.05*i for i in range(10)])
c_array.extend([0.5 + 0.1*i for i in range(1,16)])
c_array = np.array(c_array)

# Fig1.A
M_array_A = np.array([25850, 37950, 29850, 36150, 21350, 29850, 39800, 45950, 67650, 78250, 99800, 104750,
                    140200,187750, 277200, 305600, 353650, 409300, 429750, 497400, 575750, 666400, 850350,
                      850350, 937450, 1033500, 1256150])

# Fig1.C
M_array_C = np.array([34450, 39800, 45950, 37950, 31300, 28450, 43800, 58500, 61400, 95050, 109950, 115400,
                      162250, 228100, 305600, 291050, 389850, 429750, 548350, 575750, 734650, 734650, 771350,
                      937450, 984300, 1196350, 1196350])

# Fig1.B
M_array_B = np.array([82150, 55750, 71000, 64450, 45950, 53100, 48200, 25850, 36150, 28450, 28450, 17650, 
                      6950, 6350, 8300, 8300, 10000, 11550, 13300, 14600, 17650, 19400, 20350, 22400, 25850, 
                      31300, 29850])

# Fig1.D.
M_array_D = np.array([64450, 67650, 61400, 50600, 55750, 39800, 53100, 45950, 31300, 21350, 18500, 14600,
                     9100, 8300, 8300, 9100, 11000, 11550, 13950, 16050, 18500, 20350, 23500, 25850, 28450,
                      31300, 32850])

# %%
plt.figure(figsize=(10,7))
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.plot(c_array, M_array_B, 'ob', markersize=8, fillstyle='none', label='RR-F (n=16, d=3)')
plt.plot(c_array, M_array_D, 'xr', markersize=8, fillstyle='none', label='RR-SG (n=16, d=3)')
plt.xlabel(r"$c_\lambda$")
plt.ylabel(r"$m^\star$")
plt.legend(loc='best')
#plt.title('Sensitivity of Sample Complexity for GD-RISE in M-regime')
title_plot='sensitivity_D-RISE_Mregime_RR.png'
plt.savefig(title_plot, dpi=300, bbox_inches='tight')

# %%
plt.figure(figsize=(10,7))
plt.rcParams['axes.labelsize'] = 24
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.plot(c_array, M_array_A, 'sg', markersize=8, fillstyle='none', label='Lattice-F (n=16, d=4)')
plt.plot(c_array, M_array_C, 'dm', markersize=8, fillstyle='none', label='Lattice-SG (n=16, d=4)')
plt.xlabel(r"$c_\lambda$")
plt.ylabel(r"$m^\star$")
plt.legend(loc='best')
plt.yscale('log')
#plt.title('Sensitivity of Sample Complexity for GD-RISE in M-regime')
title_plot='sensitivity_D-RISE_Mregime_Lattice.png'
plt.savefig(title_plot, dpi=300, bbox_inches='tight')

# %%
c_array
# Out:
# [0.6,
#  0.7,
#  0.8,
#  0.9,
#  1.0,
#  1.1,
#  1.2000000000000002,
#  1.3,
#  1.4,
#  1.5,
#  1.6,
#  1.7000000000000002,
#  1.8,
#  1.9000000000000001,
#  2.0]
